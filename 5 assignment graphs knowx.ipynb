# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = sns.load_dataset("iris")

# Create a scatter plot
sns.relplot(x="sepal_length", y="sepal_width", data=data)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 12, 5, 8, 3]

# Create a scatter plot
plt.scatter(x, y, label='Data Points', color='blue', marker='o')

# Adding labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot Example')

# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 12, 5, 8, 3]

# Create a line plot
plt.plot(x, y, label='Data Line', color='green', linestyle='--', marker='o')

# Adding labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot Example')

# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load your water quality dataset (replace 'water_quality_dataset.csv' with your dataset file)
import pandas as pd
data = pd.read_csv('mohith.water quality.csv')

# Create a categorical bar plot
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

sns.barplot(x="ph", y="Hardness", data=data)

# Adding labels and title
plt.xlabel('Water Quality Parameter')
plt.ylabel('Value')
plt.title('Water Quality Parameter Bar Plot')

# Rotating x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()  # Optional: Adjust layout for better spacing
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your data)
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]

# Create a countplot
sns.countplot(x=data)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your data)
data = [15,20,33,45,67,90]

# Create a box plot
sns.boxplot(x=data)

# Display the plot
plt.show()
# Out:
# C:\Users\ch\anaconda3\envs\tokyo\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your data)
data = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

# Create a violin plot
sns.violinplot(x=data)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your data)
data = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

# Create a strip plot
sns.stripplot(x=data, jitter=True)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your data)
data = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

# Create a swarm plot
sns.swarmplot(x=data)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your data)
x = ["A", "B", "C", "A", "B", "C"]
y = [10, 15, 7, 12, 18, 9]

# Create a factor plot (formerly catplot)
sns.catplot(x=x, y=y, kind="bar")

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 9
#       6 y = [10, 15, 7, 12, 18, 9]
#       8 # Create a factor plot (formerly catplot)
# ----> 9 sns.catplot(x=x, y=y, kind="bar")
#      11 # Display the plot
#      12 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:3241, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3235     plot_kws.update(
#    3236         estimator=estimator, errorbar=errorbar,
#    3237         n_boot=n_boot, units=units, seed=seed,
#    3238     )
#    3240 # Initialize the facets
# -> 3241 g = FacetGrid(**facet_kws)
#    3243 # Draw the plot onto the facets
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your data)
data = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

# Create a histogram plot
sns.histplot(data, bins=10, kde=True)  # You can adjust the number of bins and enable KDE as needed

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your data)
data = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

# Create a distribution plot
sns.displot(data, kde=True)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your data)
x = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60]
y = [10, 12, 18, 14, 22, 20, 24, 28, 26, 30]

# Create a joint plot
sns.jointplot(x=x, y=y, kind="scatter")

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your dataset)
data = sns.load_dataset("iris")  # Load the Iris dataset as an example

# Create a pair plot
sns.pairplot(data, hue="species")  # "species" is a categorical variable for color differentiation

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your data)
data = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

# Create a rug plot
sns.rugplot(data)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your data)
data = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

# Create a KDE plot
sns.kdeplot(data, shade=True)

# Display the plot
plt.show()
# Out:
# C:\Users\ch\AppData\Local\Temp\ipykernel_1512\4170118522.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data, shade=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd  # Import Pandas for reading the CSV file

# Load your own dataset
data = pd.read_csv("mohith.water quality.csv")  # Replace "heart.csv" with the actual file path if needed

# Create a scatter plot
sns.lmplot(x="ph", y="Hardness", data=data)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd  # Import Pandas for reading the CSV file

# Load your own dataset
data = pd.read_csv("mohith.water quality.csv")  # Replace "heart.csv" with the actual file path if needed

# Create a scatter plot with a linear regression line
sns.regplot(x="Sulfate", y="Solids", data=data)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your dataset)
data = sns.load_dataset("iris")  # Load the Iris dataset as an example

# Create a pairplot (matrix plot)
sns.pairplot(data, hue="species")  # "species" is a categorical variable for color differentiation

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace this with your dataset)
data = sns.load_dataset("flights")  # Load the Flights dataset as an example

# Pivot the data into a matrix
pivot_data = data.pivot_table(index='month', columns='year', values='passengers')

# Create a heatmap
sns.heatmap(pivot_data, cmap='YlGnBu')

# Display the plot
plt.show()

# %%
import numpy as np
import seaborn as sns

def calculate_statistics_and_identify_outliers(data):
    # Calculate the mean and median
    mean = np.mean(data)
    median = np.median(data)
    
    # Calculate the interquartile range (IQR)
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    IQR = Q3 - Q1

    # Calculate the lower and upper bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = [x for x in data if x < lower_bound or x > upper_bound]

    return mean, median, outliers

# Example usage
data = [15, 20, 21, 25, 30, 32, 33, 34, 35, 45, 50, 200]  # Your dataset goes here
mean, median, outliers = calculate_statistics_and_identify_outliers(data)

print("Mean:", mean)
print("Median:", median)
print("Outliers:", outliers)
sns.boxplot(x=data)
# Out:
# Mean: 45.0
# Median: 32.5
# Outliers: [200]
# C:\Users\ch\anaconda3\envs\tokyo\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: >
